# %%
#unsupervised PCA (principle component analysis)
#used for reducing dimensionality

#reinforcement ML
#:Q-LEARNING= i)agent ii)environment iii)state iv)action v)episode vii)discount factor viii)penalty and reward

# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

iris = load_iris()

X = iris.data
y = iris.target

# Standardization
scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)


pca = PCA(n_components=2)

X_pca = pca.fit_transform(X_scaled)


df = pd.DataFrame(
    X_pca,
    columns=["PC1","PC2"]
)

print(df.head())


print("Explained Variance Ratio")
print(pca.explained_variance_ratio_)


plt.figure(figsize=(8,6))

plt.scatter(
    X_pca[:,0],
    X_pca[:,1],
    c=y
)

plt.xlabel("PC1")
plt.ylabel("PC2")
plt.title("PCA")

plt.show()
# Out:
#         PC1       PC2
# 0 -2.264703  0.480027
# 1 -2.080961 -0.674134
# 2 -2.364229 -0.341908
# 3 -2.299384 -0.597395
# 4 -2.389842  0.646835
# Explained Variance Ratio
# [0.72962445 0.22850762]
