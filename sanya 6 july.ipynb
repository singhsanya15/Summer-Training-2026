# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

img=Image.open(r"C:\Users\Sanya\Desktop\summer training\shortcake.jpg")
img=np.array(img)
img[:,:,0]=np.clip(img[:,:,0]+10,0,255)
plt.imshow(img)
plt.axis("off")
plt.show()

# %%
import pandas as pd
df=pd.DataFrame({"name":["sanya","mehak","divyank"],"marks":[10,20,30]})
df
# Out:
#       name  marks
# 0    sanya     10
# 1    mehak     20
# 2  divyank     30
