# %%
# !pip install keras
# Out:
# Requirement already satisfied: keras in c:\users\sanya\anaconda3\lib\site-packages (3.15.0)
# Requirement already satisfied: absl-py in c:\users\sanya\anaconda3\lib\site-packages (from keras) (2.5.0)
# Requirement already satisfied: numpy in c:\users\sanya\anaconda3\lib\site-packages (from keras) (2.3.5)
# Requirement already satisfied: rich in c:\users\sanya\anaconda3\lib\site-packages (from keras) (14.2.0)
# Requirement already satisfied: namex in c:\users\sanya\anaconda3\lib\site-packages (from keras) (0.1.0)
# Requirement already satisfied: h5py in c:\users\sanya\anaconda3\lib\site-packages (from keras) (3.14.0)
# Requirement already satisfied: optree in c:\users\sanya\anaconda3\lib\site-packages (from keras) (0.19.1)
# Requirement already satisfied: ml-dtypes in c:\users\sanya\anaconda3\lib\site-packages (from keras) (0.5.4)
# Requirement already satisfied: packaging in c:\users\sanya\anaconda3\lib\site-packages (from keras) (25.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\sanya\anaconda3\lib\site-packages (from optree->keras) (4.15.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\sanya\anaconda3\lib\site-packages (from rich->keras) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\sanya\anaconda3\lib\site-packages (from rich->keras) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\sanya\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\sanya\anaconda3\lib\site-packages (2.21.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\sanya\anaconda3\lib\site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\sanya\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in c:\users\sanya\anaconda3\lib\site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\sanya\anaconda3\lib\site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\sanya\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\sanya\anaconda3\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\sanya\anaconda3\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\sanya\anaconda3\lib\site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in c:\users\sanya\anaconda3\lib\site-packages (from tensorflow) (7.35.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\sanya\anaconda3\lib\site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in c:\users\sanya\anaconda3\lib\site-packages (from tensorflow) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\sanya\anaconda3\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\sanya\anaconda3\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\sanya\anaconda3\lib\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\sanya\anaconda3\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\sanya\anaconda3\lib\site-packages (from tensorflow) (1.82.1)
# Requirement already satisfied: keras>=3.12.0 in c:\users\sanya\anaconda3\lib\site-packages (from tensorflow) (3.15.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\sanya\anaconda3\lib\site-packages (from tensorflow) (2.3.5)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in c:\users\sanya\anaconda3\lib\site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\sanya\anaconda3\lib\site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\sanya\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sanya\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sanya\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sanya\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.11.12)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\sanya\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in c:\users\sanya\anaconda3\lib\site-packages (from keras>=3.12.0->tensorflow) (14.2.0)
# Requirement already satisfied: namex in c:\users\sanya\anaconda3\lib\site-packages (from keras>=3.12.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\users\sanya\anaconda3\lib\site-packages (from keras>=3.12.0->tensorflow) (0.19.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\sanya\anaconda3\lib\site-packages (from rich->keras>=3.12.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\sanya\anaconda3\lib\site-packages (from rich->keras>=3.12.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\sanya\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow) (0.1.2)

# %%
import numpy as np
import pandas as pd
import keras
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import keras.models as km
from keras.models import Sequential
from keras import activations, initializers, regularizers, constraints
from keras.layers import Dense, Activation

# %%
df=pd.read_csv("wine.csv")
df
# Out:
#      fixed_acidity  residual_sugar  alcohol  density quality_label
# 0              9.3             6.4     13.6   1.0005          high
# 1             11.2             2.0     14.0   0.9912        medium
# 2             11.6             0.9      8.2   0.9935           low
# 3             12.9             6.6     12.7   1.0002           low
# 4             13.9            13.8     10.4   0.9942        medium
# ..             ...             ...      ...      ...           ...
# 995           13.0             4.3     13.1   1.0035           low
# 996            6.4             5.3      9.5   1.0040           low
# 997            4.5             9.0     13.8   0.9931        medium
# 998            5.3            12.2      8.1   0.9955           low
# 999            7.6            14.3     10.1   0.9924          high
#
# [1000 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# fixed_acidity     0
# residual_sugar    0
# alcohol           0
# density           0
# quality_label     0
# dtype: int64

# %%
df["quality_label"].value_counts()
# Out:
# quality_label
# medium    355
# high      343
# low       302
# Name: count, dtype: int64

# %%
X = df.drop(columns=["quality_label"])
y = df['quality_label']

# %%
X=pd.get_dummies(X)
y=pd.get_dummies(y)

# %%
train_X, test_X, train_y, test_y = train_test_split(X, y, test_size=0.3, random_state =123)

# %%
train_X.shape
# Out:
# (700, 4)

# %%
sc = StandardScaler()
train_X = sc.fit_transform(train_X)
test_X = sc.transform(test_X)

# %%
train_X.shape
# Out:
# (700, 4)

# %%
model = Sequential()
model.add(Dense(units = 4, kernel_initializer = 'uniform', activation = 'relu', input_dim = 4))
model.add(Dense(units = 3, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dense(units = 2, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'linear'))
# Out:
# C:\Users\Sanya\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 4)                   │              20 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 3)                   │              15 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 2)                   │               8 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1)                   │               3 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 46 (184.00 B)
#  Trainable params: 46 (184.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
print(train_X.shape)
print(train_y.shape)
# Out:
# (700, 4)
# (700, 3)

# %%
model.fit(train_X, train_y, epochs=50, batch_size=32, validation_split=0.1)

mse = model.evaluate(test_X, test_y)
print(f'Test Mean Squared Error: {mse}')
# Out:
# Epoch 1/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 0.3272 - val_loss: 0.3204
# Epoch 2/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3148 - val_loss: 0.3086
# Epoch 3/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3034 - val_loss: 0.2978
# Epoch 4/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2931 - val_loss: 0.2880
# Epoch 5/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2839 - val_loss: 0.2793
# Epoch 6/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2756 - val_loss: 0.2715
# Epoch 7/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2682 - val_loss: 0.2645
# Epoch 8/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2616 - val_loss: 0.2584
# Epoch 9/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2558 - val_loss: 0.2529
# Epoch 10/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2507 - val_loss: 0.2482
# Epoch 11/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2462 - val_loss: 0.2441
# Epoch 12/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2423 - val_loss: 0.2405
# Epoch 13/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2390 - val_loss: 0.2374
# Epoch 14/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2361 - val_loss: 0.2348
# Epoch 15/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2337 - val_loss: 0.2325
# Epoch 16/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2316 - val_loss: 0.2306
# Epoch 17/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2299 - val_loss: 0.2290
# Epoch 18/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2284 - val_loss: 0.2277
# Epoch 19/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2272 - val_loss: 0.2266
# Epoch 20/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2262 - val_loss: 0.2257
# Epoch 21/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2254 - val_loss: 0.2250
# Epoch 22/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2247 - val_loss: 0.2244
# Epoch 23/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2242 - val_loss: 0.2239
# Epoch 24/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2237 - val_loss: 0.2235
# Epoch 25/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2234 - val_loss: 0.2232
# Epoch 26/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2231 - val_loss: 0.2230
# Epoch 27/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2229 - val_loss: 0.2228
# Epoch 28/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2227 - val_loss: 0.2227
# Epoch 29/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2226 - val_loss: 0.2225
# Epoch 30/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2225 - val_loss: 0.2225
# Epoch 31/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2224 - val_loss: 0.2224
# Epoch 32/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2224 - val_loss: 0.2224
# Epoch 33/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2223 - val_loss: 0.2223
# Epoch 34/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2223 - val_loss: 0.2223
# Epoch 35/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2223 - val_loss: 0.2223
# Epoch 36/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2223 - val_loss: 0.2223
# Epoch 37/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2223 - val_loss: 0.2222
# Epoch 38/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2222 - val_loss: 0.2222
# Epoch 39/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2222 - val_loss: 0.2222
# Epoch 40/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2222 - val_loss: 0.2222
# Epoch 41/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2222 - val_loss: 0.2222
# Epoch 42/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2222 - val_loss: 0.2222
# Epoch 43/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2222 - val_loss: 0.2222
# Epoch 44/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2222 - val_loss: 0.2222
# Epoch 45/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2222 - val_loss: 0.2222
# Epoch 46/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2222 - val_loss: 0.2222
# Epoch 47/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2222 - val_loss: 0.2222
# Epoch 48/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2222 - val_loss: 0.2222
# Epoch 49/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2222 - val_loss: 0.2222
# Epoch 50/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2222 - val_loss: 0.2222
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2222
# Test Mean Squared Error: 0.22222237288951874

# %%
predictions = model.predict(test_X)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step

# %%
predictions
# Out:
# array([[0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086],
#        [0.33297086]], dtype=float32)
